# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r"C:\Users\amitd\OneDrive\Desktop\Python Bootcamp\Loan payments data.csv")

# %%
dataset
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.shape
# Out:
# (500, 11)

# %%
dataset.drop(columns = ["past_due_days"], inplace = True)

# %%
dataset.shape
# Out:
# (500, 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.fillna(10)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  age             education  Gender
# ...

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.fillna(method = "bfill")
# Out:
# C:\Users\amitd\AppData\Local\Temp\ipykernel_13444\1509449636.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "bfill")
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# ...

# %%
dataset.fillna(method = "ffill")
# Out:
# C:\Users\amitd\AppData\Local\Temp\ipykernel_13444\1261878897.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "ffill")
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# ...

# %%
dataset.fillna(method = "bfill", axis=1)
# Out:
# C:\Users\amitd\AppData\Local\Temp\ipykernel_13444\916175640.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method = "bfill", axis=1)
#          Loan_ID         loan_status Principal terms effective_date  \
# 0    xqd20166231             PAIDOFF      1000    30       9/8/2016
# 1    xqd20168902             PAIDOFF      1000    30       9/8/2016
# 2    xqd20160003             PAIDOFF      1000    30       9/8/2016
# 3    xqd20160004             PAIDOFF      1000    15       9/8/2016
# 4    xqd20160005             PAIDOFF      1000    30       9/9/2016
# ..           ...                 ...       ...   ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF      1000    30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF      1000    15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF       800    15      9/12/2016
# ...

# %%
dataset.describe()
# Out:
#          Principal       terms         age
# count   500.000000  500.000000  500.000000
# mean    943.200000   22.824000   31.116000
# std     115.240274    8.000064    6.084784
# min     300.000000    7.000000   18.000000
# 25%    1000.000000   15.000000   27.000000
# 50%    1000.000000   30.000000   30.000000
# 75%    1000.000000   30.000000   35.000000
# max    1000.000000   30.000000   51.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   age             500 non-null    int64
#  8   education       500 non-null    object
#  9   Gender          500 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 39.2+ KB

# %%
dataset["paid_off_time"].mode()[0]
# Out:
# '9/25/2016 9:00'

# %%
dataset["age"].mode()[0]
# Out:
# np.int64(26)

# %%
dataset.select_dtypes(include="object").isnull().columns
# Out:
# Index(['Loan_ID', 'loan_status', 'effective_date', 'due_date', 'paid_off_time',
#        'education', 'Gender'],
#       dtype='object')

# %%
for i in dataset.select_dtypes(include="object").isnull().columns:
    print(i)
# Out:
# Loan_ID
# loan_status
# effective_date
# due_date
# paid_off_time
# education
# Gender

# %%
for i in dataset.select_dtypes(include="object").isnull().columns:
    dataset[i] = dataset[i].fillna(dataset[i].mode()[0])

# %%
dataset.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# age               0
# education         0
# Gender            0
# dtype: int64
