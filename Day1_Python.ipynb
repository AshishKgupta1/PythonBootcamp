# %%
a = int(input("Enter First Number: "))
b = int(input("Enter Second Number: "))
print(a+b)
# Out:
# Enter First Number: 5
# Enter Second Number: 45
# 50

# %%
Name1 = "Ashish", "Ayush"
Name2 = "Rahul", "Saksham"
print(Name1, Name2)
# Out:
# ('Ashish', 'Ayush') ('Rahul', 'Saksham')

# %%
a = ""'My name is Ashish'""
print(type(a))
# Out:
# <class 'str'>

# %%
Fname = input("Enter Your Name: ")
Sname = input("Enter Your Surname: ")
print(len(Fname+" "+Sname))
# Out:
# Enter Your Name: Ashish
# Enter Your Surname: Gupta
# 12

# %%
age = int(input("Enter Your Age: "))
if age <= 12:
  print("You are Child!")
elif age > 12 and age <= 19:
  print("You are Teen")
elif age > 19 and age < 35:
  print("You are Young Adult")
elif age >= 35 and age <= 65:
  print("You are Adult")
else:
  print("You are Senior Citizen")
# Out:
# Enter Your Age: 35
# You are Adult

# %%
marks = int(input("Enter Your Marks: "))
if marks < 30:
  print("You have Failed")
elif marks >= 30 and marks <= 45:
  print("Grade : E")
elif marks > 45 and marks <= 60:
  print("Grade : D")
elif marks > 60 and marks <= 70:
  print("Grade : C")
elif marks > 70 and marks < 90:
  print("Grade : B")
elif marks >= 90:
  print("Grade : A")
# Out:
# Enter Your Marks: 50
# Grade : D

# %%
value = int(input("Enter a Number: "))
if value > 5 :
  print("Number is greater than 5")
else :
  print("Number is less than 5")
# Out:
# Enter a Number: 6
# Number is greater than 5

# %%
num = int(input("Enter a Number: "))
if num%7 == 0:
  print("Number is divisible by 7")
else:
  print("Number is not divisible by 7")
# Out:
# Enter a Number: 5
# Number is not divisible by 7

# %%
num = int(input("Enter a Number: "))
if num%5 == 0:
  print("Hello!")
else:
  print("Bye!")
# Out:
# Enter a Number: 2
# Bye!

# %%
list = [12, 45, 85, 68, 42, 71, 56, 27]
list.append(46)
print(list)
# Out:
# [12, 45, 85, 68, 42, 71, 56, 27, 46]

# %%
list = [12, 45, 85, 68, 42, 71, 56, 27]
list.sort()
print(list)
# Out:
# [12, 27, 42, 45, 56, 68, 71, 85]

# %%
list = [12, 45, 85, 68, 42, 71, 56, 27]
list.reverse()
print(list)
# Out:
# [27, 56, 71, 42, 68, 85, 45, 12]

# %%
list = [12, 45, 85, 68, 42, 71, 56, 27]
list.sort(reverse = True)
print(list)
# Out:
# [85, 71, 68, 56, 45, 42, 27, 12]

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka"]
list.append("Ashish")
print(list)
# Out:
# ['Aman', 'Kunal', 'Kamal', 'Vivek', 'Anushka', 'Ashish']

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka", "Ashish"]
list.sort()
print(list)
# Out:
# ['Aman', 'Anushka', 'Ashish', 'Kamal', 'Kunal', 'Vivek']

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka", "Ashish"]
list.reverse()
print(list)
# Out:
# ['Ashish', 'Anushka', 'Vivek', 'Kamal', 'Kunal', 'Aman']

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka", "Ashish"]
list.sort(reverse = True)
print(list)
# Out:
# ['Vivek', 'Kunal', 'Kamal', 'Ashish', 'Anushka', 'Aman']

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka"]
list.insert(2, "Nikhil")
print(list)
# Out:
# ['Aman', 'Kunal', 'Nikhil', 'Kamal', 'Vivek', 'Anushka']

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka"]
list.remove("Anushka")
print(list)
# Out:
# ['Aman', 'Kunal', 'Kamal', 'Vivek']

# %%
list = ["Aman", "Kunal", "Kamal", "Vivek", "Anushka"]
list.pop(2)
print(list)
# Out:
# ['Aman', 'Kunal', 'Vivek', 'Anushka']
